# %%
import cv2
import AnalyzerModule as pm
import numpy as np
import mediapipe as mp
import math
import matplotlib.pyplot as plt
import pandas as pd
from scipy.signal import savgol_filter

# %%
#cap = cv2.VideoCapture('/Users/edwardzhang/Desktop/Codes/Project/Videos/Ray Shooting.MOV')
detector = pm.poseDetector()

path = 'Videos/Ray.MOV'
joints = [pm.SHOULDER_RIGHT,pm.HIP_RIGHT,pm.KNEE_RIGHT,pm.ANKLE_RIGHT,pm.ELBOW_RIGHT]

detector.analyze(path,joints)

# %%
# Out:
# 44

# %%
detector.output_graph()

# %%
detector2 = pm.poseDetector()
path2 = 'Videos/Jeremy.MOV'
detector2.analyze(path2,joints)

# %%
detector2.output_graph()
# Out:
# NoneType

# %%
joints = [pm.SHOULDER_RIGHT,pm.HIP_RIGHT,pm.KNEE_RIGHT,pm.ANKLE_RIGHT,pm.ELBOW_RIGHT]
limbs = [pm.ARM_LOWER_RIGHT,pm.ARM_UPPER_RIGHT,pm.UPPER_BODY_RIGHT,pm.LEG_UPPER_RIGHT,pm.LEG_LOWER_RIGHT, pm.FOOT_RIGHT]
pm.pipeline(path = path, output_name = 'pipeline_output',joints=joints,limbs=limbs)

# %%
plt.plot(alpha.Knee)
